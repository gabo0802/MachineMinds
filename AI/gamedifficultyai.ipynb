# %%
import pandas as pd
import numpy as np

# %%
import sklearn
from sklearn import datasets
from sklearn import preprocessing
from sklearn import metrics
from sklearn import model_selection

# %%
game_data = pd.read_csv('Data/data.csv') #data as .csv file?

# %%
game_data
# Out:
#      index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0        0         P1   33       1              2            4             5
# 1        1        P10   17       1              3            1             5
# 2        2       P100   35       1              4            5             6
# 3        3      P1000   37       1              7            7             7
# 4        4       P101   46       1              6            8             7
# ..     ...        ...  ...     ...            ...          ...           ...
# 995    995       P995   44       1              6            7             7
# 996    996       P996   37       2              6            8             7
# 997    997       P997   25       2              4            5             6
# 998    998       P998   18       2              6            8             7
# 999    999       P999   47       1              6            5             6
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  ...  Fatigue  \
# 0                       4             3                     2  ...        3
# 1                       3             4                     2  ...        1
# 2                       5             5                     4  ...        8
# 3                       7             6                     7  ...        4
# 4                       7             7                     6  ...        3
# ..                    ...           ...                   ...  ...      ...
# 995                     7             7                     6  ...        5
# 996                     7             7                     6  ...        9
# 997                     5             5                     4  ...        8
# 998                     7             7                     6  ...        3
# 999                     5             5                     4  ...        8
#
#      Weight Loss  Shortness of Breath  Wheezing  Swallowing Difficulty  \
# 0              4                    2         2                      3
# 1              3                    7         8                      6
# 2              7                    9         2                      1
# 3              2                    3         1                      4
# 4              2                    4         1                      4
# ..           ...                  ...       ...                    ...
# 995            3                    2         7                      8
# 996            6                    5         7                      2
# 997            7                    9         2                      1
# 998            2                    4         1                      4
# 999            7                    9         2                      1
#
#      Clubbing of Finger Nails  Frequent Cold  Dry Cough  Snoring   Level
# 0                           1              2          3        4     Low
# 1                           2              1          7        2  Medium
# 2                           4              6          7        2    High
# 3                           5              6          7        5    High
# 4                           2              4          2        3    High
# ..                        ...            ...        ...      ...     ...
# 995                         2              4          5        3    High
# 996                         4              3          1        4    High
# 997                         4              6          7        2    High
# 998                         2              4          2        3    High
# 999                         4              6          7        2    High
#
# [1000 rows x 26 columns]

# %% [markdown]
# ## Data Preprocesing

# %%
#possible data cleaning would go here

# %%
#normalizing data

# %%
#split data into training and testing data
X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(x, y, train_size = 0.8, test_size = 0.2)

# %% [markdown]
# ## AI Model Training

# %%
#need to decide AI model

# %%
#Linear regression (temporary need to to decided model from previous line)
from sklearn.linear_model import LogisticRegression
logistic_reg = LogisticRegression()

logistic_reg.fit(X_train, y_train)

# %% [markdown]
# ## Testing Model Accuracy + Other Metrics

# %%
y_predict = logistic_reg.predict(X_test)

# %%
sklearn.metrics.accuracy_score(y_test, y_predict)

# %%
sklearn.metrics.precision_recall_fscore_support(y_test, y_predict) #might need to add average = 'macro'
